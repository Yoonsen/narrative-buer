# %% [markdown]
# # Narration
#
# Vi ser på hvordan punktuering, og andre høyfrekvente ord utvikler seg i en tekst.

# %%
from dhlab.module_update import css
import narration_code as nc
import dhlab.text as dh

# %%
import importlib as i

# %%
i.reload(nc)
# Out:
# <module 'narration_code' from '/mnt/disk1/Github/narrative-buer/narration_code.py'>

# %%
css()
# Out:
# <style>@import url(http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# p {
#     font-size:1.3em;
#     font-family:serif;
#     line-height:1.4em;
#     color:#142850;
# }
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# /*
# .prompt, .jp-InputPrompt, .jp-InputArea-prompt, .jp-OutputPrompt, .jp-OutputArea-prompt {
#     visibility: hidden;
# }
#
#
# .jp-CodeCell .jp-Notebook-cell    {
#     margin-left:10%;
#     margin-right:5%;
# }
#
#
# .jp-InputArea, .jp-OutputArea {
#     margin-left:2.5em;
#     margin-right:2.5em;
# }
# */
#
#
# body  {
#     margin:10%;
#     counter-reset: h1counter;
#
# }
#
# /* .jp-MarkdownOutput, .text_cell_render {
#
#     background-color:#FEFBF1;
#     border-style: solid;
#     border-width: 1px;
#     border-color: rgba(0,0,0, 0.10);;
# } */
#
#
# h1:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 50%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:3px solid SlateGray; /* FireBrick; */
# }
#
# h2:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 30%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:2px solid SlateGray; /* FireBrick; */
# }
#
# </style>

# %% [markdown]
# Bygg korpus

# %%
corpus = dh.Corpus(doctype = "digibok", author= "nansen", limit = 10)
corpus.corpus[['urn', 'title','authors','year', 'subjects']]
# Out:
#                                    urn  \
# 0  URN:NBN:no-nb_digibok_2020070348564
# 1  URN:NBN:no-nb_digibok_2020041448078
# 2  URN:NBN:no-nb_digibok_2009042700015
# 3  URN:NBN:no-nb_digibok_2009060403002
# 4  URN:NBN:no-nb_digibok_2009092810001
# 5  URN:NBN:no-nb_digibok_2009052903024
# 6  URN:NBN:no-nb_digibok_2009052903014
# 7  URN:NBN:no-nb_digibok_2009070110004
# 8  URN:NBN:no-nb_digibok_2016090848252
# 9  URN:NBN:no-nb_digibok_2008121012004
#
#                                                title  \
# 0                  Første Fram-ferd 1890-92 : planen
# 1  La travesía de Groenlandia : relato de la exp...
# 2  På ski over fjellet ; På ski over Grønland ; F...
# 3                                   Russia and peace
# 4                                        Eskimo life
# 5                                        Eskimo life
# 6                                          Eskimoliv
# 7  Tvende Motioner, fremsatte paa Norges ordentli...
# 8                            Seppala : hundekjøreren
# 9                             Eva og Fridtjof Nansen
#
#                                              authors  year  \
# 0   Nansen , Fridtjof / Kløver , Geir O. (Geir Olav)  2020
# 1  Nansen , Fridtjof / Nansen , Fridtjof / Puerta...  2018
# 2                                  Nansen , Fridtjof  1994
# 3                                  Nansen , Fridtjof  1923
# 4                                  Nansen , Fridtjof  1894
# 5                                  Nansen , Fridtjof  1893
# 6                 Nansen , Fridtjof / Sinding , Otto  1891
# 7                            Nansen , Hans Lejerdahl  1815
# 8                                 Nansen , Elizabeth  1932
# 9                                 Høyer , Liv Nansen  1954
#
#                                             subjects
# 0                      Polarekspedisjoner / mannskap
# 1                                             Reiser
# 2  Geografi / Feltarbeid / Polarforskning / skitu...
# 3
# 4                            greenland / ethnography
# 5                            greenland / ethnography
# 6  Inuitter / Folketro / Dagligliv / Inuitter / e...
# 7                                         Grunnloven
# 8  Innvandring / Norsk-amerikanere / arktis / ala...
# 9  biografi/genealogi / polfarere / arktis / biog...

# %% [markdown]
# Plot i to runder, en med dh.Dispersion, og en med narration_code som nc, nc.display() - noen ganger henger det skikkelig - andre ganger ligger dh.Dispersion() ca. 10 ganger så lang tid.

# %%
# %%time
for row in corpus.corpus.iterrows():
    urn = row[1]["urn"]
    title = row[1]['title']
    dh.Dispersion(urn=urn, wordbag=['.'], window=1000, pr=100).plot(title=title, figsize=(12,5))
# Out:
# CPU times: user 717 ms, sys: 14.9 ms, total: 732 ms
# Wall time: 5.04 s

# %%
# %%time
nc.display(corpus)
# Out:
# CPU times: user 578 ms, sys: 41.2 ms, total: 619 ms
# Wall time: 2.31 s

# %% [markdown]
# Vi prøver med et korpus fra Derrida

# %%
derrida = dh.Corpus(author="Derrida", limit = 20)
derrida.corpus[['urn', 'title','authors','year', 'subjects']]
# Out:
#                                    urn  \
# 0  URN:NBN:no-nb_digibok_2015021106159
# 1  URN:NBN:no-nb_digibok_2020091607536
# 2  URN:NBN:no-nb_digibok_2008062501030
# 3  URN:NBN:no-nb_digibok_2011032508114
# 4  URN:NBN:no-nb_digibok_2011082308261
#
#                                                title  \
# 0    Lovens makt : "autoritetenes mystiske grunnlag"
# 1  Sannheten i maleriet : restitusjoner av sannhe...
# 2  Marx' spøkelser : gjeldsstaten, sorgarbeidet o...
# 3                          Adjø til Emmanuel Levinas
# 4        Dekonstruksjon : klassiske tekster i utvalg
#
#                                              authors  year  \
# 0  Derrida , Jacques / Ekeland , Bjørn C. / Ekela...  2002
# 1  Derrida , Jacques / Hammer , Espen / Myklebust...  2004
# 2              Derrida , Jacques / Gundersen , Karin  1996
# 3  Derrida , Jacques / Myklebust , Ragnar Braasta...  2002
# 4              Derrida , Jacques / Gundersen , Karin  2006
#
#                                             subjects
# 0  Rettsfilosofi / lover / rettsfilosofi / filoso...
# 1  Kunst / Filosofi og teori / Filosofi / Kunstte...
# 2  Marxisme / marxisme / kommunisme / 1990-tallet...
# 3           Filosofi / Filosofer / fransk / filosofi
# 4  Dekonstruktivisme / Dekonstruksjon / fransk / ...

# %% [markdown]
# Her er kurvene for punktum i noen (ikke alle bøkene i korpuset lot seg vise)

# %%
nc.display(derrida)
